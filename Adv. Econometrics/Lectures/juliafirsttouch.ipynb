# %% [markdown]
# # Julia First Touch

# %%
# requirements
using LinearAlgebra
using Statistics
using Plots
using Distributions

# %% [markdown]
# ## Random Variables

# %%
n = 30
xbar = Vector{Float64}(undef, 200000)
for j in 200000
    x = randn(n)
    xbar[j] = mean(x)
end
# Out:
# 9.280730340565609e-7

# %% [markdown]
# ## Computing Statistics

# %%
mean(xbar)
var(xbar)
